# %% [markdown]
# ## Python Class

# %%
x=5
print(x)
# Out:
# 5

# %%
x=22
y=44
y
x
# Out:
# 22

# %%
x=56
y=4.5
print(x)
print(y)
# Out:
# 56
# 4.5

# %%
type(y)
# Out:
# float

# %%
x=2
y=4
print(x+y)
# Out:
# 6

# %%
x=8
y=3
z=x-y
print(z)
# Out:
# 5

# %%
t=100
i=80
d=t*i
print(d)
r=t/i
print(r)
j=t//i  #floor Division
print(j)
type(j)
g=2
k=5
g**k  #Exponental
# Out:
# 8000
# 1.25
# 1
# 32

# %%
u=5   #Modulo operator
g=3
print(u%g)   #%=Remainder
# Out:
# 2

# %% [markdown]
# ###Boolean

# %%
x=2
y=4
print(x==y)
# Out:
# False

# %%
p=2
d=2
p==d
# Out:
# True

# %%
p=9
s=7
p!=s
# Out:
# True

# %%
w=9
t=7
w<t
# Out:
# False

# %%
100>99
# Out:
# True

# %%
s=33
f=55
print(s<=f)
# Out:
# True

# %%
print("hello chethan")

print("i'm chethan")  # here donot use single coat('  ')
# Out:
# hello chethan
# i'm chethan

# %%
True  #boolean
true  #nothing
"chethan"  #String
"1234"    #String
1233    #Integer
2.455  #float
'333'  #String
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3450316070.py in <cell line: 0>()
#       1 True  #boolean
# ----> 2 true  #nothing
#       3 "chethan"  #String
#       4 "1234"    #String
#       5 1233    #Integer
#
# NameError: name 'true' is not defined

# %%
print("Hello"+'  '+str(5))
# Out:
# Hello  5

# %%
print("Hello"," "+"5")
# Out:
# Hello  5

# %%
main():      #:=Statement
 dsdfd     #This line space is called Indentation & this line belong to above Statement
 fghhm
print(   )
# Out:
#   File "/tmp/ipython-input-1321493511.py", line 1
#     main():      #:=Statement
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##Global & Local Variable

# %%
f=100      #Global var
print(f)

def func1():    #define the function    # Local var
  f=50
  print(f)

func1()     #Calling function
print(f)

def func2():
  f=200
  print(f)

print(f)
func1()
func2()
# Out:
# 100
# 50
# 100
# 100
# 50
# 200

# %% [markdown]
# ##String Index[-1]

# %%
string = "my name is CHETHAN."
print(string)
print(string[0:5])    #Starting Index & Ending Index-1
print(string[:6])
print(string[0])
print(string[2])
print(string[::6])
len(string)
print(string[:])
print(string[4:])
# Out:
# my name is CHETHAN.
# my na
# my nam
# m
#
# meH.
# my name is CHETHAN.
# ame is CHETHAN.

# %% [markdown]
# ##Len()

# %%
given = "computer"
print(len(given))
# Out:
# 8

# %% [markdown]
# ##Upper & Lower Cases

# %%
k="battle shipwar"
print(k.upper())
print(k.lower())
# Out:
# BATTLE SHIPWAR
# battle shipwar

# %% [markdown]
# ##Count()

# %%
f="i am good coder goo"
print(f.count('o'))
print(f.count('goo'))
# Out:
# 5
# 2

# %% [markdown]
# ##replace()

# %%
a="i am sorry"
print(a.replace('sorry','ok'))
# Out:
# i am ok

# %% [markdown]
# ##Strip()

# %%
#remove the space
p="   how are you   "
x=p.strip()
print(x)
print(p.strip())
p=d=p.strip()
print(p)
print(d)
# Out:
# how are you
# how are you
# how are you
# how are you

# %% [markdown]
# ##Split()

# %%
v="virat khloi"
print(v.split(" "))
print(v.split('v'))
print(v.split('t'))
print(v.split('l'))
# Out:
# ['virat', 'khloi']
# ['', 'irat khloi']
# ['vira', ' khloi']
# ['virat kh', 'oi']

# %% [markdown]
# ###Extra

# %%
name = "chethan"
#print "hi chethan 8"
print("hi"+ " "+ name + " " + "8")
# Out:
# hi chethan 8

# %% [markdown]
# ##Conditional Statements

# %% [markdown]
# ##if

# %%
x=2   # x=20
if x==20 :
  print("x is gretaer than 10!")
  print("YES, you are correct")

print("I dont follow Identtation")
# Out:
# I dont follow Identtation

# %% [markdown]
# ##if & else

# %%
city = "Honnali"
if city == "Honnali":
  print("welcome to honnali")
else:
  print("not a Honnali")
# Out:
# welcome to honnali

# %%
name = "channa"
if name == "channamma" :
 print("she is my mother")
else:
  print("shee is not a mother")
# Out:
# shee is not a mother

# %% [markdown]
# ##if, else & elif

# %%
city = 'Davanagere'
if city == "Delhi"  :
  print("Welcome to Captial city of India")
elif city == "Davanagere" :
  print("wel to city of Butter!")
else :
  print('Where are you?'+ "\ncome to Benglore")
# Out:
# wel to city of Butter!

# %%
q = -5
if q > 0:
  print("Greater")
elif q==0 :
  print("Zero")
else:
  print("lesser")
# Out:
# lesser

# %% [markdown]
# ## Nested & if

# %%
a=29     # a= 0 ,a= -9
if a>=0 :
  if a==0 :
    print("Zero")
  else:
    print("Greater")
else:
  print("Lesser")
# Out:
# Greater 29

# %% [markdown]
# ## Loop Statements

# %% [markdown]
# ##While & For

# %%
x = 0
while x<=5 :   #  Works only till the condition is true
  print(x)
  x=x+1
print("I came out to loop")
print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# I came out to loop
# 6

# %%
for x in range(10,15) :
  print(x)
# Out:
# 10
# 11
# 12
# 13
# 14

# %%
listt=["apple","ball","cat",222,123,23.09,True]
print(listt)
for r in listt:
  print(r)
print(type(r))
# Out:
# ['apple', 'ball', 'cat', 222, 123, 23.09, True]
# apple
# ball
# cat
# 222
# 123
# 23.09
# True
# <class 'bool'>

# %%
# The list of Nmubers
list_of_numbers = [1,2,3,4,5,6,99]
print(list_of_numbers.index(99))
# print there squares
for numbers in list_of_numbers :
  squared_numbers = numbers**2
  print(f"The Square of {numbers} is {squared_numbers}")
# Out:
# 6
# The Square of 1 is 1
# The Square of 2 is 4
# The Square of 3 is 9
# The Square of 4 is 16
# The Square of 5 is 25
# The Square of 6 is 36
# The Square of 99 is 9801

# %% [markdown]
# ##Enumerate

# %%
listt=["apple","ball","cat",222,123,23.09,True]
for index,value in enumerate(listt):
  print(index,value)
# Out:
# 0 apple
# 1 ball
# 2 cat
# 3 222
# 4 123
# 5 23.09
# 6 True

# %% [markdown]
# ##Break() & Continue()

# %%
for i in range (5):
  if i==3:
    break
  print(i)
  i=i+1
# Out:
# 0
# 1
# 2

# %%
i=1
while i<=10:
  print("6 *" , i ,"=", 6*i)
  if i>=5:
    break
  i=i+1
# Out:
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30

# %%
for i in range(5):
  if i==3:
    continue
  print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
# To print even & odd Numbers
i=0
while i<=10:
  if(i%2==0):
    print(i)


  i=i+1
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
a = 0
while a < 10:
  a+=1            #DOUGHT THIS LINE
  if (a % 2)!= 0:
      continue
  print(a)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ##Collection Types

# %% [markdown]
# #####1.List = Collection of ordered & change elements,Allows Duplicate
# ##### 2.Tuple = ordered & unchanged elements , Allows Duplicate
# ##### 3. Set = unordered & unisexd elements, Duplicates are not Allowed
# ##### 4. Dictonary = unordered,, changable & indexed , Duplicates are not Allowed

# %%
fruits = ["apple", "mango", "orange", "banana"]
print(fruits)
print(len(fruits))
print(fruits.count("apple"))
print(type(fruits))
# Out:
# ['apple', 'mango', 'orange', 'banana']
# 4
# 1
# <class 'list'>

# %%
for x in fruits:
  print(x)
# Out:
# apple
# mango
# orange
# banana

# %%
fruits = ["apple", "mango", "orange", "banana"]
print(fruits[0])
print(fruits[-1])
print(fruits[2:])
print(fruits[0:])
print(fruits[1:3])
print(fruits[-3:-1])    #Ending Index = -1-1=-2
print(fruits[-2:])
# Out:
# apple
# banana
# ['orange', 'banana']
# ['apple', 'mango', 'orange', 'banana']
# ['mango', 'orange']
# ['mango', 'orange']
# ['orange', 'banana']

# %%
fruits = ["apple", "mango", "orange", "banana"]
print(fruits)
fruits[2]="coconuts"
print(fruits)
# Out:
# ['apple', 'mango', 'orange', 'banana']
# ['apple', 'mango', 'coconuts', 'banana']

# %%
fruits = ["apple", "mango", "orange", "banana"]
if "apple" in fruits:
  print("yes")
else:
  print("no")
# Out:
# yes

# %%
fruits = ["apple", "mango", "orange", "banana"]
fruits.append("Carrot")
print(fruits)
# Out:
# ['apple', 'mango', 'orange', 'banana', 'Carrot']

# %%
fruits = ["apple", "mango", "orange", "banana"]
fruits.insert(3,"carrot")
print(fruits)
# Out:
# ['apple', 'mango', 'orange', 'carrot', 'banana']

# %%
fruits = ["apple", "mango", "orange", "banana"]
fruits.pop()
print(fruits)
fruits.remove("apple")
print(fruits)
# Out:
# ['apple', 'mango', 'orange']
# ['mango', 'orange']

# %%
fruits = ["apple", "mango", "orange", "banana"]
a=fruits
print(a)
b=fruits.copy()
print(b)
b.pop()
print(a,b)
# Out:
# ['apple', 'mango', 'orange', 'banana']
# ['apple', 'mango', 'orange', 'banana']
# ['apple', 'mango', 'orange', 'banana'] ['apple', 'mango', 'orange']

# %% [markdown]
# ### Tuples

# %%
veg = ("carrot" , "raddish" , "onion" , "tomato" , "cucumber")
print(veg[0])
print(veg[-1])
print(veg[2:])
print(veg[0:])
print(veg[1:3])
print(veg[-3:-1])
print(veg[-2:])
# Out:
# carrot
# cucumber
# ('onion', 'tomato', 'cucumber')
# ('carrot', 'raddish', 'onion', 'tomato', 'cucumber')
# ('raddish', 'onion')
# ('onion', 'tomato')
# ('tomato', 'cucumber')

# %%
veg = ("carrot" , "raddish" , "onion" , "tomato" , "cucumber")
aaa = ("chilly" ,200)
print(veg+aaa)
print(type(aaa))
# Out:
# ('carrot', 'raddish', 'onion', 'tomato', 'cucumber', 'chilly', 200)
# <class 'tuple'>

# %%
veg = ("carrot" , "raddish" , "onion" , "tomato" , "cucumber")
veg[2]= "Grapes"
print(veg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1953780888.py in <cell line: 0>()
#       1 veg = ("carrot" , "raddish" , "onion" , "tomato" , "cucumber")
# ----> 2 veg[2]= "Grapes"
#       3 print(veg)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ###Sets { }

# %%
sett = {"onion" , "cucumber" , "raddish" , "carrot" , "carrot"}
print(sett)
print(type(sett))
# Out:
# {'onion', 'cucumber', 'carrot', 'raddish'}
# <class 'set'>

# %%
x = {"onion" , "cucumber" , "raddish" , "carrot" , "carrot"}
for stt in x:
  print(stt)
x.add("mango")
print(x)
# Out:
# onion
# cucumber
# carrot
# raddish
# {'onion', 'raddish', 'mango', 'cucumber', 'carrot'}

# %%
sett = {"onion" , "cucumber" , "raddish" , "carrot"}
sett.update({"cauli" , "brokli"})
sett
sett.discard("onion")
sett
sett.remove("cucumber")
sett
# Out:
# {'brokli', 'carrot', 'cauli', 'raddish'}

# %%
sett = {"onion" , "cucumber" , "raddish" , "carrot"}
sett.pop()  # set not take pop()
sett
# Out:
# {'carrot', 'cucumber', 'raddish'}

# %% [markdown]
# ##Dictionaries

# %%
# It is a collection which unordered, changable & indexed
# It contain keys & Value

# %%
person = {"name":"chethan" , "age":22 , "gender":"male"}
person
# Out:
# {'name': 'chethan', 'age': 22, 'gender': 'male'}

# %%
#Access a value
person = {"name":"chethan" , "age":22 , "gender":"male"}
year = person['name']
year
# Out:
# 'chethan'

# %%
# change a value
person = {"name":"chethan" , "age":22 , "gender":"male"}
person['age']=99
person
# Out:
# {'name': 'chethan', 'age': 99, 'gender': 'male'}

# %%
person = {"name":"chethan" , "age":22 , "gender":"male"}
for x in person:
  print(x)
# Out:
# name
# age
# gender

# %%
person = {"name":"chethan" , "age":22 , "gender":"male"}
for key in person :
  print(person[key])
# Out:
# chethan
# 22
# male

# %%
person = {"name":"chethan" , "age":22 , "gender":"male"}
for y in person:
  print(y,person[y])
# Out:
# name chethan
# age 22
# gender male

# %%
# values are used to get the values of dict
person = {"name":"chethan" , "age":22 , "gender":"male"}
for value in person.values():
  print(value)
# Out:
# chethan
# 22
# male

# %%
# items are used to get all elements from dict
person = {"name":"chethan" , "age":22 , "gender":"male"}
for key,value in person.items():
  print(key,value)
# Out:
# name chethan
# age 22
# gender male

# %%
person = {"name":"chethan" , "age":22 , "gender":"male"}
print(len(person))
print(type(person))
# Out:
# 3
# <class 'dict'>

# %%
person = {"name":"chethan" , "age":22 , "gender":"male"}
person['weight'] = 57
person
# Out:
# {'name': 'chethan', 'age': 22, 'gender': 'male', 'weight': 57}

# %%
person = {"name":"chethan" , "age":22 , "gender":"male"}
person.pop('gender')
person
# Out:
# {'name': 'chethan', 'age': 22}

# %%
person = {"name":"chethan" , "age":22 , "gender":"male"}
person1={"weight":99}
aa ={**person1,**person}
aa
# Out:
# {'weight': 99, 'name': 'chethan', 'age': 22, 'gender': 'male'}

# %% [markdown]
# ##Functions()

# %%
def function():
  print("Hello World")
function()   # Call that function!
# Out:
# Hello World

# %%
def gretting(name):   #name as a Parameter
  print("Daddys " + name)
gretting('home')
# Out:
# Daddys home

# %%
def fun(n1,n2):
  a=n1   # n1 stored in a
  b=n2
  print(a,b)
fun(10,20)
# Out:
# 10 20

# %%
def function(name,seat):
  print("welcome " + name + "\nyour seat number " + seat)
function("ah","22")
print("please take ypur seat")
print("   ")
function("che","66")
# Out:
# welcome ah
# your seat number 22
# please take ypur seat
#
# welcome che
# your seat number 66

# %%
def greytting(name,classs = '09'):  # max 2 parameters are Allowed & only last value is default parameter
  print("welcome " + name + "\nyour class number is "+ classs)
greytting("che")
greytting("pk","100")
greytting("yoy")
# Out:
# welcome che
# your class number is 09
# welcome pk
# your class number is 100
# welcome yoy
# your class number is 09

# %%
def square(x):
  print(x*x)
square(2)
# Out:
# 4

# %%
def square(x):
  return x*x
print("hello")
print(square(6))
x=square(3)
print(x)
# Out:
# hello
# 36
# 9
